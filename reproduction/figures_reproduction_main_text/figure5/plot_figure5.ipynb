# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
VOI_list = list()
for idx in [-1,0,1,2,3,4,5]:
    voi_dict_SegNeuro2D_star = np.load('./CL_voi_dict_SegNeuro2D(star)Cumulative_{}.npy'.format(idx), allow_pickle=True).item()
    for key in voi_dict_SegNeuro2D_star.keys():
        VOI_list.extend([[item[0],item[1],item[0]+item[1],idx] for item in voi_dict_SegNeuro2D_star[key]])
df_VOI_Cumulative = pd.DataFrame(data=VOI_list,columns=['VOI Split', 'VOI Merge', 'VOI', 'Index'],index=None)

# %%
VOI_list = list()
for idx in [-1,0,1,2,3,4,5]:
    voi_dict_SegNeuro2D_star = np.load('./CL_voi_dict_SegNeuro2D(star)EWC_{}.npy'.format(idx), allow_pickle=True).item()
    for key in voi_dict_SegNeuro2D_star.keys():
        VOI_list.extend([[item[0],item[1],item[0]+item[1],idx] for item in voi_dict_SegNeuro2D_star[key]])
df_VOI_EWC = pd.DataFrame(data=VOI_list,columns=['VOI Split', 'VOI Merge', 'VOI', 'Index'],index=None)

# %%
VOI_list = list()
for idx in [-1,0,1,2,3,4,5]:
    voi_dict_SegNeuro2D_star = np.load('./CL_voi_dict_SegNeuro2D(star)Naive_{}.npy'.format(idx), allow_pickle=True).item()
    for key in voi_dict_SegNeuro2D_star.keys():
        VOI_list.extend([[item[0],item[1],item[0]+item[1],idx] for item in voi_dict_SegNeuro2D_star[key]])
df_VOI_Naive = pd.DataFrame(data=VOI_list,columns=['VOI Split', 'VOI Merge', 'VOI', 'Index'],index=None)

# %%
VOI_list = list()
for idx in [-1,0,1,2,3,4,5]:
    voi_dict_SegNeuro2D_star = np.load('./CL_voi_dict_SegNeuro2D(star)Replay_{}.npy'.format(idx), allow_pickle=True).item()
    for key in voi_dict_SegNeuro2D_star.keys():
        VOI_list.extend([[item[0],item[1],item[0]+item[1],idx] for item in voi_dict_SegNeuro2D_star[key]])
df_VOI_Replay = pd.DataFrame(data=VOI_list,columns=['VOI Split', 'VOI Merge', 'VOI', 'Index'],index=None)

# %%
VOI_list = list()
for idx in [-1,0,1,2,3,4,5]:
    voi_dict_SegNeuro2D_star = np.load('./CL_voi_dict_SegNeuro2D(star)AGEM_{}.npy'.format(idx), allow_pickle=True).item()
    for key in voi_dict_SegNeuro2D_star.keys():
        VOI_list.extend([[item[0],item[1],item[0]+item[1],idx] for item in voi_dict_SegNeuro2D_star[key]])
df_VOI_AGEM = pd.DataFrame(data=VOI_list,columns=['VOI Split', 'VOI Merge', 'VOI', 'Index'],index=None)

# %%
VOI_list = list()
for idx in [-1,0,1,2,3,4,5]:
    voi_dict_SegNeuro2D_star = np.load('./CL_voi_dict_SegNeuro2D(star)GDumb_{}.npy'.format(idx), allow_pickle=True).item()
    for key in voi_dict_SegNeuro2D_star.keys():
        VOI_list.extend([[item[0],item[1],item[0]+item[1],idx] for item in voi_dict_SegNeuro2D_star[key]])
df_VOI_GDumb = pd.DataFrame(data=VOI_list,columns=['VOI Split', 'VOI Merge', 'VOI', 'Index'],index=None)

# %%
VOI_list = list()
for idx in [-1,0,1,2,3,4,5]:
    voi_dict_SegNeuro2D_star = np.load('./CL_voi_dict_SegNeuro2D(star)SynapticIntelligence_{}.npy'.format(idx), allow_pickle=True).item()
    for key in voi_dict_SegNeuro2D_star.keys():
        VOI_list.extend([[item[0],item[1],item[0]+item[1],idx] for item in voi_dict_SegNeuro2D_star[key]])
df_VOI_SI = pd.DataFrame(data=VOI_list,columns=['VOI Split', 'VOI Merge', 'VOI', 'Index'],index=None)

# %%
metric = 'VOI'
plt.figure(figsize=(12,6))
# y_baseline_joint = [np.mean(df_VOI[df_VOI['Index']==idx][metric]) for idx in range(7)]
# plt.plot(np.arange(7), y_baseline_joint, 'b*--', alpha=0.5, linewidth=1, label='baseline')
y_Cumulative = [np.mean(df_VOI_Cumulative[df_VOI_Cumulative['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Cumulative, 'r*--', alpha=1, linewidth=1, markersize=10, label='Cumulative')

y_Naive = [np.mean(df_VOI_Naive[df_VOI_Naive['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Naive, 'kd--', alpha=1, linewidth=1, markersize=10, label='Naive')

y_Replay = [np.mean(df_VOI_Replay[df_VOI_Replay['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Replay, 'bo--', alpha=1, linewidth=1, markersize=10, label='Replay')

y_EWC = [np.mean(df_VOI_EWC[df_VOI_EWC['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_EWC, 'g^--', alpha=1, linewidth=1, markersize=10, label='EWC')

y_AGEM = [np.mean(df_VOI_AGEM[df_VOI_AGEM['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_AGEM, '*--',c='darkorange', alpha=1, linewidth=1, markersize=10, label='AGEM')

y_GDumb = [np.mean(df_VOI_GDumb[df_VOI_GDumb['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_GDumb, 'yv--', alpha=1, linewidth=1, markersize=10, label='GDumb')

y_SI = [np.mean(df_VOI_SI[df_VOI_SI['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_SI, 'mX--', alpha=1, linewidth=1, markersize=10, label='SynapticIntelligence')

plt.xlabel('Number of experience on zebrafinch data',fontsize=20)
plt.ylabel(metric,fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=20)

# plt.show()
plt.savefig('./figure5a1.pdf', dpi=300)

# %%
metric = 'VOI Merge'
plt.figure(figsize=(12,6))
# y_baseline_joint = [np.mean(df_VOI[df_VOI['Index']==idx][metric]) for idx in range(7)]
# plt.plot(np.arange(7), y_baseline_joint, 'b*--', alpha=0.5, linewidth=1, label='baseline')
y_Cumulative = [np.mean(df_VOI_Cumulative[df_VOI_Cumulative['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Cumulative, 'r*--', alpha=1, linewidth=1, markersize=10, label='Cumulative')

y_Naive = [np.mean(df_VOI_Naive[df_VOI_Naive['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Naive, 'kd--', alpha=1, linewidth=1, markersize=10, label='Naive')

y_Replay = [np.mean(df_VOI_Replay[df_VOI_Replay['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Replay, 'bo--', alpha=1, linewidth=1, markersize=10, label='Replay')

y_EWC = [np.mean(df_VOI_EWC[df_VOI_EWC['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_EWC, 'g^--', alpha=1, linewidth=1, markersize=10, label='EWC')

y_AGEM = [np.mean(df_VOI_AGEM[df_VOI_AGEM['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_AGEM, '*--',c='darkorange', alpha=1, linewidth=1, markersize=10, label='AGEM')

y_GDumb = [np.mean(df_VOI_GDumb[df_VOI_GDumb['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_GDumb, 'yv--', alpha=1, linewidth=1, markersize=10, label='GDumb')

y_SI = [np.mean(df_VOI_SI[df_VOI_SI['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_SI, 'mX--', alpha=1, linewidth=1, markersize=10, label='SynapticIntelligence')

plt.xlabel('Number of experience on zebrafinch data',fontsize=20)
plt.ylabel(metric,fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=20)

# plt.show()
plt.savefig('./figure5a2.pdf', dpi=300)

# %%
metric = 'VOI Split'
plt.figure(figsize=(12,6))
# y_baseline_joint = [np.mean(df_VOI[df_VOI['Index']==idx][metric]) for idx in range(7)]
# plt.plot(np.arange(7), y_baseline_joint, 'b*--', alpha=0.5, linewidth=1, label='baseline')
y_Cumulative = [np.mean(df_VOI_Cumulative[df_VOI_Cumulative['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Cumulative, 'r*--', alpha=1, linewidth=1, markersize=10, label='Cumulative')

y_Naive = [np.mean(df_VOI_Naive[df_VOI_Naive['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Naive, 'kd--', alpha=1, linewidth=1, markersize=10, label='Naive')

y_Replay = [np.mean(df_VOI_Replay[df_VOI_Replay['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_Replay, 'bo--', alpha=1, linewidth=1, markersize=10, label='Replay')

y_EWC = [np.mean(df_VOI_EWC[df_VOI_EWC['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_EWC, 'g^--', alpha=1, linewidth=1, markersize=10, label='EWC')

y_AGEM = [np.mean(df_VOI_AGEM[df_VOI_AGEM['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_AGEM, '*--',c='darkorange', alpha=1, linewidth=1, markersize=10, label='AGEM')

y_GDumb = [np.mean(df_VOI_GDumb[df_VOI_GDumb['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_GDumb, 'yv--', alpha=1, linewidth=1, markersize=10, label='GDumb')

y_SI = [np.mean(df_VOI_SI[df_VOI_SI['Index']==idx][metric]) for idx in range(-1,6)]
plt.plot(np.arange(7), y_SI, 'mX--', alpha=1, linewidth=1, markersize=10, label='SynapticIntelligence')

plt.xlabel('Number of experience on zebrafinch data',fontsize=20)
plt.ylabel(metric,fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize=20)

# plt.show()
plt.savefig('./figure5a3.pdf', dpi=300)

# %%
plt.figure(figsize=(12,6))
training_time = {'baseline-1':459, 'baseline-2':103, 'Replay':196,'EWC':108,'GDumb':366,'SynapticIntelligence':121,'AGEM':267}
# strategies = ['baseline-1','baseline-2','Replay','EWC','GDumb','SynapticIntelligence','AGEM']
strategies = ['baseline-1','GDumb','AGEM','Replay','SynapticIntelligence','EWC','baseline-2']
colors = {'baseline-1':'r','baseline-2':'k','Replay':'b','EWC':'g','GDumb':'y','SynapticIntelligence':'m','AGEM':'darkorange'}
for idx in range(len(strategies)):
    strategy = strategies[idx]
    time = training_time[strategy]
    color = colors[strategy]
    plt.bar(idx, height=time, width=0.5, color=color, label=strategy)
plt.xticks(list(range(len(strategies))),strategies,rotation=0)
plt.xlabel('Online Training Strategy')
plt.ylabel('Training Time (minute) for six volumes')
plt.savefig('./figure5b.pdf', dpi=300)
